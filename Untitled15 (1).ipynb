# %%
import numpy as np
import matplotlib.pyplot as plt
N=100
k=500
A=[]
[A.append(max(np.random.laplace(size=N))) for i in range(k)]
plt.plot(A,'ro')

# %%
xx=np.linspace(0,100)
yy=list(map(lambda x:(-0.5*x/(np.exp(abs(x))*abs(x)))**N,xx))
plt.plot(xx,yy)
# Out:
# <ipython-input-180-fe376fed29bb>:2: RuntimeWarning: invalid value encountered in double_scalars
#   yy=list(map(lambda x:(-0.5*x/(np.exp(abs(x))*abs(x)))**N,xx))
